# %%
import pandas as pd
import seaborn as sns
from scipy.optimize import curve_fit
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
display(df.shape)
# Out:
# (2838325, 10)

# %%
from scipy import stats

# %time 

z = np.abs(stats.zscore(df['petroleo_Mbd']))
print(z)

threshold = 3
print(np.where(z > 3))
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 10 µs
# [0.25101138 0.25101138 0.25101138 ... 0.25101138 0.25101138 0.24852182]
# (array([ 843979,  844268,  844567, ..., 1667026, 1683582, 1809365]),)

# %%
# %time 
display(z)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 14.3 µs
# array([0.25101138, 0.25101138, 0.25101138, ..., 0.25101138, 0.25101138,
#        0.24852182])

# %%
# %time 

fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['fecha'],df['petroleo_Mbd'])
ax.set_xlabel('Fecha')
ax.set_ylabel('Produccion Aceite (Mbd)')
plt.show()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.06 µs

# %%
df.shape
df_c=df[['fecha','petroleo_Mbd']]

#df_o = df_c[(z > 3).all(axis=0)]
df_o = df_c[(z > 3)]
display(df_c.shape,df_o.shape)
# Out:
# (2838325, 2)
# (72221, 2)

# %%
pozos=df.set_index('fecha','pozo')

# %%
pozos.plot()
