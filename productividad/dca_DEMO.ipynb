# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import dca
# Out:
# 'Tiempo de procesamiento: 10.205648205999996 segundos'

# %%
dca.run_dca()
# Out:
# Nombre de campo/contrato/asignacion: LOS SOLDADOS
# Numero de campos de analisis:
# Analisis DCA Analogos (Y/''):
# Tomar muestra desde fecha (yyyy-mm-dd):
# Generar archivos (Y/''):
# Régimen Fiscal:
# Regalía Adicional Decimales:
# 'Número de pozos en LOS SOLDADOS: 144'
#             produccion_mensual_campo_Mbd
# fecha
# 2016-05-01                          5.11
# pozos_perforados               144.00
# pozos_productores               98.00
# pozos_secos                     46.00
# exito_mecanico                   0.68
# EUR_por_pozo_MMb                 0.19
# pozos_activos                   28.00
# pozos_cerrados                  70.00
# produccion_mensual_media_Mbd     0.06
# produccion_mensual_max_MMb       1.40
# EUR_max_MMb                      1.28
# Q_base                           1.70
# Qg_base                          5.63
# Qc_base                          0.00
# Np                              43.63
# Gp                             114.91
# ...

# %%
from dca import *

# %%
df=perfil.media_M+perfil.alta_M+perfil.baja_M
df.plot()

df1=perfil.alta_M
df1.plot(linestyle='dotted',color='blue')

df2=perfil.media_M
df2.plot(linestyle='dotted',color='green')

df3=perfil.baja_M
df3.plot(linestyle='dotted',color='red')
